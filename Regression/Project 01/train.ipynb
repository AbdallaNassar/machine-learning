# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor

# %%
df =pd.read_csv("train.csv")
df.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
df.isnull().sum()
# Out:
# x    5
# y    3
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=.8)
plt.scatter(x_train,y_train,color="red")
plt.show()

# %%
model =LinearRegression()
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.9908468728434834
# 0.9895399321210294

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,model.predict(x_test) ,color ="red")
plt.show()

# %%
#Neural Network
neural_model=MLPRegressor(hidden_layer_sizes=[64,128,246],learning_rate="constant",learning_rate_init=.0001,max_iter=500)
neural_model.fit(x_train,y_train)
print(neural_model.score(x_train,y_train))
print(neural_model.score(x_test,y_test))
# Out:
# 0.9908457607307415
# 0.9895347164556548
